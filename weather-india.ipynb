# %%
import pandas as pd
data = pd.read_csv('/kaggle/input/indian-weather-repository-daily-snapshot/IndianWeatherRepository.csv')
print(data.head())
print(data.info())
print(data.describe())
# Out:
#   country location_name          region  latitude  longitude      timezone  \
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1693286100  2023-08-29 10:45                 27.5
# 1          1693286100  2023-08-29 10:45                 27.5
# 2          1693286100  2023-08-29 10:45                 26.3
# 3          1693286100  2023-08-29 10:45                 25.6
# 4          1693286100  2023-08-29 10:45                 27.2
#
#    temperature_fahrenheit  ... air_quality_PM2.5  air_quality_PM10  \
# 0                    81.5  ...              12.6              18.5
# 1                    81.5  ...              10.7              14.2
# 2                    79.3  ...              16.8              20.7
# 3                    78.1  ...               4.9               6.6
# 4                    81.0  ...              11.4              14.8
#
#    air_quality_us-epa-index  air_quality_gb-defra-index   sunrise    sunset  \
# 0                         1                           2  05:59 AM  06:41 PM
# 1                         1                           1  06:00 AM  06:40 PM
# 2                         2                           2  05:56 AM  06:34 PM
# 3                         1                           1  06:00 AM  06:38 PM
# 4                         1                           1  06:01 AM  06:39 PM
#
#    moonrise   moonset      moon_phase  moon_illumination
# 0  05:42 PM  03:38 AM  Waxing Gibbous                 93
# 1  05:39 PM  03:41 AM  Waxing Gibbous                 93
# 2  05:32 PM  03:39 AM  Waxing Gibbous                 93
# 3  05:36 PM  03:43 AM  Waxing Gibbous                 93
# 4  05:38 PM  03:42 AM  Waxing Gibbous                 93
#
# [5 rows x 42 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32276 entries, 0 to 32275
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       32276 non-null  object
#  1   location_name                 32276 non-null  object
#  2   region                        32276 non-null  object
#  3   latitude                      32276 non-null  float64
#  4   longitude                     32276 non-null  float64
#  5   timezone                      32276 non-null  object
#  6   last_updated_epoch            32276 non-null  int64
#  7   last_updated                  32276 non-null  object
#  8   temperature_celsius           32276 non-null  float64
#  9   temperature_fahrenheit        32276 non-null  float64
#  10  condition_text                32276 non-null  object
#  11  wind_mph                      32276 non-null  float64
#  12  wind_kph                      32276 non-null  float64
#  13  wind_degree                   32276 non-null  int64
#  14  wind_direction                32276 non-null  object
#  15  pressure_mb                   32276 non-null  float64
#  16  pressure_in                   32276 non-null  float64
#  17  precip_mm                     32276 non-null  float64
#  18  precip_in                     32276 non-null  float64
#  19  humidity                      32276 non-null  int64
#  20  cloud                         32276 non-null  int64
#  21  feels_like_celsius            32276 non-null  float64
#  22  feels_like_fahrenheit         32276 non-null  float64
#  23  visibility_km                 32276 non-null  float64
#  24  visibility_miles              32276 non-null  float64
#  25  uv_index                      32276 non-null  float64
#  26  gust_mph                      32276 non-null  float64
#  27  gust_kph                      32276 non-null  float64
#  28  air_quality_Carbon_Monoxide   32276 non-null  float64
#  29  air_quality_Ozone             32276 non-null  float64
#  30  air_quality_Nitrogen_dioxide  32276 non-null  float64
#  31  air_quality_Sulphur_dioxide   32276 non-null  float64
#  32  air_quality_PM2.5             32276 non-null  float64
#  33  air_quality_PM10              32276 non-null  float64
#  34  air_quality_us-epa-index      32276 non-null  int64
#  35  air_quality_gb-defra-index    32276 non-null  int64
#  36  sunrise                       32276 non-null  object
#  37  sunset                        32276 non-null  object
#  38  moonrise                      32276 non-null  object
#  39  moonset                       32276 non-null  object
#  40  moon_phase                    32276 non-null  object
#  41  moon_illumination             32276 non-null  int64
# dtypes: float64(23), int64(7), object(12)
# memory usage: 10.3+ MB
# None
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  32276.000000  32276.000000        3.227600e+04         32276.000000
# mean      23.098196     80.237351        1.695768e+09            23.622438
# std        5.796415      5.757514        1.465803e+06             4.250263
# min        8.080000     68.970000        1.693286e+09           -10.900000
# 25%       20.270000     76.070000        1.694473e+09            22.000000
# 50%       23.970000     78.680000        1.695766e+09            24.100000
# 75%       26.770000     83.900000        1.697059e+09            26.000000
# max       34.570000     95.800000        1.698266e+09            38.300000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            32276.000000  32276.000000  32276.000000  32276.000000
# mean                74.520415      5.110519      8.230131    179.495817
# std                  7.649895      3.059479      4.916186    106.154734
# min                 12.400000      2.200000      3.600000      1.000000
# 25%                 71.700000      2.700000      4.300000     79.000000
# 50%                 75.500000      4.300000      6.800000    200.000000
# 75%                 78.800000      6.500000     10.400000    270.000000
# max                100.900000     26.800000     43.200000    360.000000
#
#         pressure_mb   pressure_in  ...      gust_kph  \
# count  32276.000000  32276.000000  ...  32276.000000
# mean    1007.738660     29.758021  ...     14.604644
# std        4.167822      0.122921  ...      8.037322
# min      997.000000     29.440000  ...      0.000000
# 25%     1005.000000     29.670000  ...      8.600000
# 50%     1007.000000     29.740000  ...     13.600000
# 75%     1011.000000     29.850000  ...     19.100000
# max     1029.000000     30.380000  ...     75.600000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                 32276.000000       32276.000000
# mean                    655.995681          27.126373
# std                     581.588840          23.710760
# min                     113.500000           0.000000
# 25%                     317.100000           9.000000
# 50%                     500.700000          21.600000
# 75%                     801.100000          39.000000
# max                   13565.100000         234.600000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                  32276.000000                 32276.000000
# mean                      10.542762                     4.743460
# std                       10.882859                    11.109487
# min                        0.000000                     0.000000
# 25%                        3.600000                     1.000000
# 50%                        7.300000                     2.200000
# 75%                       13.700000                     4.800000
# max                      189.200000                   541.700000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count       32276.000000      32276.000000              32276.000000
# mean           61.946641         75.817084                  2.680568
# std            70.188644         83.104187                  1.391694
# min             0.500000          0.700000                  1.000000
# 25%            14.300000         18.900000                  1.000000
# 50%            39.200000         50.200000                  2.000000
# 75%            85.100000        104.425000                  4.000000
# max          1374.800000       1498.000000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count                32276.000000       32276.000000
# mean                     5.277482          47.506971
# std                      3.713291          35.366960
# min                      1.000000           0.000000
# 25%                      2.000000          13.000000
# 50%                      4.000000          46.000000
# 75%                     10.000000          84.000000
# max                     10.000000         100.000000
#
# [8 rows x 30 columns]

# %%
import seaborn as sns
import pandas as pd
data = pd.read_csv('/kaggle/input/indian-weather-repository-daily-snapshot/IndianWeatherRepository.csv')

# Select relevant columns for correlation analysis
correlation_cols = ['temperature_celsius', 'precip_mm', 'wind_kph', 'humidity', 'air_quality_PM2.5']

# Calculate the correlation matrix
correlation_matrix = data[correlation_cols].corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       9 correlation_matrix = data[correlation_cols].corr()
#      11 # Plot the correlation matrix as a heatmap
# ---> 12 plt.figure(figsize=(10, 8))
#      13 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
#      14 plt.title('Correlation Matrix')
#
# NameError: name 'plt' is not defined

# %%
data['last_updated'] = pd.to_datetime(data['last_updated'])
data.set_index('last_updated', inplace=True)

# Plot line graph for temperature changes over time
plt.figure(figsize=(12, 6))
plt.plot(data['temperature_celsius'])
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Changes over Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 data.set_index('last_updated', inplace=True)
#       4 # Plot line graph for temperature changes over time
# ----> 5 plt.figure(figsize=(12, 6))
#       6 plt.plot(data['temperature_celsius'])
#       7 plt.xlabel('Time')
#
# NameError: name 'plt' is not defined

# %%
# Scatter plot of latitude vs. longitude to visualize geographical locations
plt.scatter(data['longitude'], data['latitude'], alpha=0.5, color='blue')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Distribution of Locations')
plt.show()
